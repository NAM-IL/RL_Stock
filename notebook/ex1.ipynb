# %%
import pandas as pd

# %%
fileName = "1_kiwoom_stock.csv"

# %%
data = pd.read_csv(fileName, sep=',', encoding='utf-8')

# %%
df0 = pd.DataFrame(data=data)
df0
# Out:
#               일자       시가       고가       저가       종가 종가 단순 5      10       20  \
# 0     2004/04/23   6075.0   6798.0   5352.0   5352.0
# 1     2004/04/26   5436.0   5740.0   5261.0   5398.0
# 2     2004/04/27   5451.0   5481.0   5032.0   5063.0
# 3     2004/04/28   5070.0   5451.0   4994.0   5443.0
# 4     2004/04/29   5116.0   5436.0   5025.0   5101.0  5271.4
# 5     2004/04/30   4910.0   5200.0   4910.0   4948.0  5190.6
# 6     2004/05/03   4773.0   4987.0   4682.0   4682.0  5047.4
# 7     2004/05/04   4690.0   4758.0   4568.0   4606.0    4956
# 8     2004/05/06   4591.0   4629.0   4416.0   4416.0  4750.6
# 9     2004/05/07   4339.0   4408.0   4225.0   4225.0  4575.4  4923.4
# 10    2004/05/10   4187.0   4187.0   3807.0   3913.0  4368.4  4779.5
# 11    2004/05/11   3913.0   4103.0   3913.0   4050.0    4242  4644.7
# 12    2004/05/12   4073.0   4149.0   3966.0   3982.0  4117.2  4536.6
# 13    2004/05/13   3883.0   3959.0   3860.0   3921.0  4018.2  4384.4
# ...

# %%
fileName_Modified = "2_kiwoom_stock_modified.csv"
data = pd.read_csv(fileName_Modified, sep=',', encoding='utf-8')
df1 = pd.DataFrame(data=data)
df1
# Out:
#               일자       시가       고가       저가       종가        거래량
# 0     2004/04/23   6075.0   6798.0   5352.0   5352.0  1415294.0
# 1     2004/04/26   5436.0   5740.0   5261.0   5398.0   343328.0
# 2     2004/04/27   5451.0   5481.0   5032.0   5063.0   299528.0
# 3     2004/04/28   5070.0   5451.0   4994.0   5443.0   182628.0
# 4     2004/04/29   5116.0   5436.0   5025.0   5101.0   109925.0
# 5     2004/04/30   4910.0   5200.0   4910.0   4948.0   107015.0
# 6     2004/05/03   4773.0   4987.0   4682.0   4682.0   144588.0
# 7     2004/05/04   4690.0   4758.0   4568.0   4606.0    95754.0
# 8     2004/05/06   4591.0   4629.0   4416.0   4416.0   101120.0
# 9     2004/05/07   4339.0   4408.0   4225.0   4225.0    67420.0
# 10    2004/05/10   4187.0   4187.0   3807.0   3913.0   102912.0
# 11    2004/05/11   3913.0   4103.0   3913.0   4050.0    60039.0
# 12    2004/05/12   4073.0   4149.0   3966.0   3982.0    43831.0
# 13    2004/05/13   3883.0   3959.0   3860.0   3921.0    86440.0
# ...
